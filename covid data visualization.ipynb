# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
covid=pd.read_csv("C:\\Users\\ADMINH\\Downloads\\Covid Live dataset.csv")
covid.head(5)
# Out:
#    # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths Total\nRecovered  \
# 0  1             USA   98,166,904     1,084,282          NaN       94,962,112
# 1  2           India   44,587,307       528,629          NaN       44,019,095
# 2  3          France   35,342,950       155,078          NaN       34,527,115
# 3  4          Brazil   34,706,757       686,027          NaN       33,838,636
# 4  5         Germany   33,312,373       149,948          NaN       32,315,200
#
#   Active\nCases Serious,\nCritical Tot Cases/\n1M pop Deaths/\n1M pop  \
# 0     2,120,510              2,970            293,206           3,239
# 1        39,583                698             31,698             376
# 2       660,757                869            538,892           2,365
# 3       182,094              8,318            161,162           3,186
# 4       847,225              1,406            397,126           1,788
#
#     Total\nTests Tests/\n1M pop     Population
# ...

# %%
covid.shape
# Out:
# (230, 13)

# %%
covid.size
# Out:
# 2990

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   #                  230 non-null    int64
#  1   Country,
# Other     230 non-null    object
#  2   Total
# Cases        230 non-null    object
#  3   Total
# Deaths       225 non-null    object
#  4   New
# Deaths         3 non-null      float64
#  5   Total
# Recovered    214 non-null    object
#  6   Active
# Cases       215 non-null    object
#  7   Serious,
# Critical  147 non-null    object
#  8   Tot Cases/
# 1M pop  228 non-null    object
#  9   Deaths/
# 1M pop     223 non-null    object
#  10  Total
# Tests        214 non-null    object
#  11  Tests/
# 1M pop      214 non-null    object
#  12  Population         228 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 23.5+ KB

# %%
covid.describe()
# Out:
#                 #  New\nDeaths
# count  230.000000          3.0
# mean   115.500000         18.0
# std     66.539462         21.0
# min      1.000000          3.0
# 25%     58.250000          6.0
# 50%    115.500000          9.0
# 75%    172.750000         25.5
# max    230.000000         42.0

# %%
covid.drop(columns="#",axis=1,inplace=True)

# %%
covid.isnull().sum()
# Out:
# Country,\nOther         0
# Total\nCases            0
# Total\nDeaths           5
# New\nDeaths           227
# Total\nRecovered       16
# Active\nCases          15
# Serious,\nCritical     83
# Tot Cases/\n1M pop      2
# Deaths/\n1M pop         7
# Total\nTests           16
# Tests/\n1M pop         16
# Population              2
# dtype: int64

# %%
me=covid["New\nDeaths"].mean()
me
# Out:
# 18.0

# %%
covid["New\nDeaths"].fillna(me,inplace=True)

# %%
mo=covid["Total\nRecovered"].mode()[0]
mo
# Out:
# '1,006,369'

# %%
covid["Total\nRecovered"].fillna(mo,inplace=True)

# %%
mo=covid["Active\nCases"].mode()[0]
mo
# Out:
# '0'

# %%
covid["Active\nCases"].fillna(mo,inplace=True)

# %%
mo=covid["Serious,\nCritical"].mode()[0]
mo
# Out:
# '1'

# %%
covid["Serious,\nCritical"].fillna(mo,inplace=True)

# %%
mo=covid["Total\nTests"].mode()[0]
mo
# Out:
# '78,646'

# %%
covid["Total\nTests"].fillna(mo,inplace=True)

# %%
mo=covid["Tests/\n1M pop"].mode()[0]
mo
# Out:
# '1,023,520'

# %%
covid["Tests/\n1M pop"].fillna(mo,inplace=True)

# %%
mo=covid["Deaths/\n1M pop"].mode()[0]
mo
# Out:
# '101'

# %%
covid["Deaths/\n1M pop"].fillna(mo,inplace=True)

# %%
covid.duplicated().sum()
# Out:
# 0

# %%
covid.dtypes
# Out:
# Country,\nOther        object
# Total\nCases           object
# Total\nDeaths          object
# New\nDeaths           float64
# Total\nRecovered       object
# Active\nCases          object
# Serious,\nCritical     object
# Tot Cases/\n1M pop     object
# Deaths/\n1M pop        object
# Total\nTests           object
# Tests/\n1M pop         object
# Population             object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
lst=[]
for i in covid.columns:
    if covid[i].dtype=="O":
        lst.append(i)
    
lst
# Out:
# ['Country,\nOther',
#  'Total\nCases',
#  'Total\nDeaths',
#  'Total\nRecovered',
#  'Active\nCases',
#  'Serious,\nCritical',
#  'Tot Cases/\n1M pop',
#  'Deaths/\n1M pop',
#  'Total\nTests',
#  'Tests/\n1M pop',
#  'Population']

# %%
for i in covid.columns:
    covid[i]=lb.fit_transform(covid[i])
covid[i]
# Out:
# 0      119
# 1        7
# 2      191
# 3       84
# 4      210
#       ...
# 225     10
# 226    205
# 227     37
# 228    187
# 229    228
# Name: Population, Length: 230, dtype: int64

# %%
covid.dtypes
# Out:
# Country,\nOther       int64
# Total\nCases          int64
# Total\nDeaths         int64
# New\nDeaths           int64
# Total\nRecovered      int64
# Active\nCases         int64
# Serious,\nCritical    int64
# Tot Cases/\n1M pop    int64
# Deaths/\n1M pop       int64
# Total\nTests          int64
# Tests/\n1M pop        int64
# Population            int64
# dtype: object

# %%
covid.plot(kind="box",subplots=True,layout=(5,5),sharex=False,sharey=True,figsize=(20,15))
# Out:
# Country,\nOther          AxesSubplot(0.125,0.749828;0.133621x0.130172)
# Total\nCases          AxesSubplot(0.285345,0.749828;0.133621x0.130172)
# Total\nDeaths          AxesSubplot(0.44569,0.749828;0.133621x0.130172)
# New\nDeaths           AxesSubplot(0.606034,0.749828;0.133621x0.130172)
# Total\nRecovered      AxesSubplot(0.766379,0.749828;0.133621x0.130172)
# Active\nCases            AxesSubplot(0.125,0.593621;0.133621x0.130172)
# Serious,\nCritical    AxesSubplot(0.285345,0.593621;0.133621x0.130172)
# Tot Cases/\n1M pop     AxesSubplot(0.44569,0.593621;0.133621x0.130172)
# Deaths/\n1M pop       AxesSubplot(0.606034,0.593621;0.133621x0.130172)
# Total\nTests          AxesSubplot(0.766379,0.593621;0.133621x0.130172)
# Tests/\n1M pop           AxesSubplot(0.125,0.437414;0.133621x0.130172)
# Population            AxesSubplot(0.285345,0.437414;0.133621x0.130172)
# dtype: object

# %%
plt.plot(covid["Total\nCases"],linestyle="dotted")

# %%
plt.plot(covid["Total\nDeaths"],linestyle="dotted")

# %%
plt.plot(covid["Total\nRecovered"],linestyle="dotted")

# %%
covid.plot(kind="scatter",x="Total\nCases",y="Total\nRecovered")
# Out:
# <AxesSubplot:xlabel='Total\nCases', ylabel='Total\nRecovered'>

# %%
x=covid["Country,\nOther"]
y=covid["Total\nCases"]

plt.bar(x,y)
plt.show()

# %%
x=covid["Total\nRecovered"]
y=covid["Total\nCases"]

plt.bar(x,y)
plt.show()

# %%
x=covid["Total\nCases"]
y=covid["Total\nRecovered"]

plt.plot(x,y)

plt.xlabel("covid cases")
plt.ylabel("death cases")

plt.show()
